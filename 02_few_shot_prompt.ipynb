# %%
import ollama

# %%
few_shot_prompt = """
Example:
Message: My laptop hangs frequently
Category: Laptop

Message: Food quality in office canteen is poor
Category: Food

Now classify the following message:
Message: Bus driver is a rash driver
Category:
"""
response = ollama.chat(
    model="llama3.2:latest",
    messages=[
        {"role": "user", "content": few_shot_prompt}
    ]
)
print(type(response))
print(response['message']['content'])
# Out:
# <class 'ollama._types.ChatResponse'>
# Based on the provided examples, I would classify the message:
#
# Message: Bus driver is a rash driver
# Category: Transportation
