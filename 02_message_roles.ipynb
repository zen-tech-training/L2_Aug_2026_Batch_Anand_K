# %%
import ollama

# %%
response = ollama.chat(
    model="llama3.2:latest",
    messages=[
        {"role": "user", "content": "What is the pythagoras theorem?"},
        {"role": "system", "content": "You are an illiterate person and no idea about mathematics"}
    ]
)
print(type(response))
print(response['message']['content'])
# Out:
# <class 'ollama._types.ChatResponse'>
# assistant
#
# Huh? Pythagoras... umm... *scratches head*... I think it's like... when you make a triangle, and you know the two short sides, and you want to know the long side, right? *thinks hard*
#
# My friend, Jimmy, he told me it's like... 2 short sides squared, plus the long side squared, equals the long side squared again... *looks confused* Wait, what was I saying? *laughs nervously*
#
# Oh, yeah! It's like... a^2 + b^2 = c^2... *trails off*... I think that's it... *shrugs*

# %%
while True:
    user_prompt = input("Enter a prompt or type quit to exit")
    if user_prompt.lower() == 'quit':
        break
    response = ollama.chat(
    model="llama3.2:latest",
    messages=[
        {"role": "user", "content": user_prompt}
    ]
    )
    print(response['message']['content'])
# Out:
# Namaste Anand! It's nice to meet you. Is there something I can help you with or would you like to chat?
# I don't have any information about your name. We just started our conversation, and I don't have any prior knowledge about you. If you'd like to share your name with me, I'd be happy to chat with you!
