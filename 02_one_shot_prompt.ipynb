# %%
import ollama

# %%
one_shot_prompt = (
    f"Example:\n"
    f"Q: Translate 'Hello, how are you?' into Hindi.\n"
    f"A: Aap kaise ho?\n\n"
    f"Now answer the following question:\n"
    f"Q: Translate 'What is your name?' in Hindi."
)
response = ollama.chat(
    model="llama3.2:latest",
    messages=[
        {"role": "user", "content": one_shot_prompt}
    ]
)
print(type(response))
print(response['message']['content'])
# Out:
# <class 'ollama._types.ChatResponse'>
# A: Aapka naam kya hai?
