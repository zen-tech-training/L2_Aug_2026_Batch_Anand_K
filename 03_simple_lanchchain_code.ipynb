# %%
#from langchain_ollama import ChatOllama
from langchain_openai import ChatOpenAI

import os
from dotenv import load_dotenv, find_dotenv

env_path = find_dotenv()
if not env_path:
    raise FileNotFoundError("Could not find .env file. Please ensure it exists in the project directory.")

load_dotenv(env_path)
openai_api_key = os.getenv("OPENAI_API_KEY")
print(f'OpenAI API Key: {openai_api_key}')

#model = ChatOllama(model="llama3.2:latest")
model = ChatOpenAI(model="gpt-4o-mini", api_key=openai_api_key)
print('LLM is ready')
# Out:
# OpenAI API Key: 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
# LLM is ready

# %%
response = model.invoke("Which is the capital city of India?")
print(type(response))
print(response)
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>
# content='The capital city of India is New Delhi.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 15, 'total_tokens': 24, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_e7eb9f2bc2', 'id': 'chatcmpl-EHQew0hdEg9K5qzzWJYWA6OYZRwJ3', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a0428a-615f-7f60-bd7e-93fc870d28f9-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 15, 'output_tokens': 9, 'total_tokens': 24, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
