# %%
import tiktoken
encoding = tiktoken.get_encoding("cl100k_base")

prompt = "Which is the capital city of India?"

#prompt = "Generative AI is a branch of AI that generates new contents"
tokens = encoding.encode(prompt)
print(len(tokens))

for token in tokens:
    print(f"{encoding.decode([token])} - {token}")
# Out:
# 8
# Which - 23956
#  is - 374
#  the - 279
#  capital - 6864
#  city - 3363
#  of - 315
#  India - 6890
# ? - 30
