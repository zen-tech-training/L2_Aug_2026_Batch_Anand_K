# %%
# Example 1 - TEXT based external knowledge base
from langchain_community.document_loaders import TextLoader
#loader = TextLoader("/content/Gen_AI.txt")
loader = TextLoader("C:\\Anand\\old_laptop_backup\\D drive data\\Anand\\material\\Training\\Gen_AI\\L2_Applied_Gen_AI\\external_knowledgebase_for_rag\\Gen_AI.txt")
docs = loader.load()

print(docs[0].page_content)
# Out:
# Generative AI (Gen AI) is a type of artificial intelligence that creates original contentâ€”such as text, images, audio, video, and computer codeâ€”in response to user prompts. Instead of just analyzing or categorizing existing data, it learns complex patterns and synthesizes entirely new material.

# %%
# Example 2 - CSV based external knowledge base
from langchain_community.document_loaders import CSVLoader

loader = CSVLoader(file_path="C:\\Anand\\old_laptop_backup\\D drive data\\Anand\\material\\Training\\Gen_AI\\L2_Applied_Gen_AI\\external_knowledgebase_for_rag\\employees.csv")
docs = loader.load()

print(docs[0].page_content)
# Out:
# ID: 1
# NAME: Tom
# CITY: Pune

# %%
# Example 3 - PDF based external knowledge base
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader(file_path="C:\\Anand\\old_laptop_backup\\D drive data\\Anand\\material\\Training\\Gen_AI\\L2_Applied_Gen_AI\\external_knowledgebase_for_rag\\Python_Programming.pdf")
docs = loader.load()

print(docs[0].page_content[:50])  # Print first 50 characters of the first page])
# Out:
# Python ProgrammingHans-Petter Halvorsen
# https://ww

# %%
# Example 4 - Web based external knowledge base
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader(web_path="https://en.wikipedia.org/wiki/Generative_AI")
docs = loader.load()

print(docs[0].page_content[:500])  # Print first 500 characters of the first page])
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# Generative AI - Wikipedia
